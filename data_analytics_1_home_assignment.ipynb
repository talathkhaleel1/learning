# %% [markdown]
# <a href="https://colab.research.google.com/github/talathkhaleel1/learning/blob/main/data_analytics_1_home_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task 1#
#
# ##Web scraping##
#
# 1) Look through and browse through the website to get yourself familiar with it. Also identify the url from which the datat has to be scraped.
#
# *Note: You may find a **href** link in **a** tag which can be used for automation of the process*
#
# 2) `Import libraries - requests, bs4, from bs4 import BeautifulSoup, Pandas, numpy, datetime, matplotlib.pyplot as plt`
#
# 3) Access webpage using requests library
#
# 4) Parse the HTML document using BeautifulSoup library
#
# 5) Inspect *HTML page* data of the url to be scraped,
#
# 6)find tags for close price, open price, marketcap and volume as per the approporiate date range (2021.08.06 --> 2021.09.05).
#
# 7)Try webscraping the data for the above

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
#  Currency = "Bitcoin"
#  start date = "06-08-2021"
#  end_date = "05-09-2021"

# %%
currency_url = "https://www.coingecko.com/en/coins/bitcoin/historical_data/usd?start_date=2021-08-06&end_date=2021-09-05#panel"
bitcoin_details = requests.get(currency_url)
bitcoin_details
# Out:
# <Response [200]>

# %%
bitcoin_currency_details = BeautifulSoup(bitcoin_details.text, "html.parser")
print(bitcoin_currency_details)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script src="https://www.googleoptimize.com/optimize.js?id=GTM-W3CD992"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/OpensearchDescription.xml" rel="search" type="application/opensearchdescription+xml">
# <title>Bitcoin USD Historical Data | CoinGecko</title>
# <meta content="Get Bitcoin (BTC) USD historical prices." name="description">
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-NP34MX7');</script>
# ...

# %% [markdown]
# Find elements using find() or find_all()

# %%
currency_name = (bitcoin_currency_details.find("div", class_="mr-md-3 tw-pl-2 md:tw-mb-0 tw-text-xl tw-font-bold tw-mb-0").text).strip()
display("Currency name = ", currency_name)
start_date = bitcoin_currency_details.find("input", class_ = "text-center px-2 py-1", attrs = {"value" : "2021-08-06"}).text
display("start_date: ", start_date)
end_date = bitcoin_currency_details.find("input", class_ = "text-center px-2 py-1", attrs = {"value" : "2021-09-05"}).text
display("end_date: ", end_date)

bitcoin_table = (bitcoin_currency_details.find("table", class_ = "table table-striped text-sm text-lg-normal").text).strip()
display(bitcoin_table)

bitcoin_array = np.array(bitcoin_table)
display(bitcoin_array)
# Out:
# 'Currency name = '
# 'Bitcoin (BTC)'
# 'start_date: '
# ''
# 'end_date: '
# ''
# ...

# %% [markdown]
# 1) convert string into list by clearing new line characters using for loop and `split(delimiter "\n" to be  specified )`- rows are formed.
#
# Now using for loop iterate through the rows and use `split(delimiter "\n" to be specified)` to remove new line characters between elements of a row.
# Use `pd.Dataframe(currency_table)` to convert the np.array into a dataframe.
#
# Alternatively, we can also extract table in two variables. One variable containing the list of the table header elements and the other the body content of the table. Then we can use currency_dictionary = dict(zip(varaible1, variable2)) so as to make them key:value pairs. Now we have a dictionary.
# Now we need to convert this dictionary into a dataframe by using `pd.DataFrame.from_dict(currency_dictionary)`
#
# 3) Next specify row and column labels, `index = column[0] and columns = ["Market_cap_currency_name", "Volume_currency_name", "Open_price_currency_name", "Close_price_currency_name"]`
# In case of dictionary conversion by default keys will be taken as column labels and then we can set the first column as index.
#
# *Note: currency_name will have to be replaced according to the dataset of dataframe. In this case, bitcoin followed by binance_coin and lastly by polkadot.*
#
# 4) Change index datatype to datetime using `dataframe ["column_name"].astype(datetime)`. Here *currency_name_dataframe["Date"].astype(datetime)*
#
# 5) Check data type using `.dtypes`. All cells with values should be of data type float. In case they are not, use `.astype(float)` to set them as float values.As we have special character of $ we will have to use the below syntax to eliminate special characters and convert data into float type.
# `dataframe.iloc[dataframe.column_name.str.replace('$','').astype(float)]`
#
# 6) After doing the above mentioned process for the other two coins. We need to concatenate the dataframes of all three coins to proceed to task two.
# This can be  done using the `pd.concat([bitcoin_dataframe, binance_coin_dataframe, polkadot_dataframe])`
# This will give us  a dataframe with index of date with datetime data type and columns for market_cap, volume, open_price and close_price with the currency name written along with the label.
#
# **Note: Below is data scraped for Binance coin and Polkadot as well.**
#
#
# **Following this is details on the remaining tasks.**

# %% [markdown]
# Currency = "Binance Coin (BNB)" start_date = "2021.08.06" end_date = "2021.09.05"

# %%
currency_binance_url = "https://www.coingecko.com/en/coins/binance-coin/historical_data/usd?start_date=2021-08-06&end_date=2021-09-05#panel"
binance_details = requests.get(currency_binance_url)
binance_details
# Out:
# <Response [200]>

# %%
binance_coin_details = BeautifulSoup(binance_details.text, "html.parser")
print(binance_coin_details)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script src="https://www.googleoptimize.com/optimize.js?id=GTM-W3CD992"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/OpensearchDescription.xml" rel="search" type="application/opensearchdescription+xml">
# <title>Binance Coin USD Historical Data | CoinGecko</title>
# <meta content="Get Binance Coin (BNB) USD historical prices." name="description">
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-NP34MX7');</script>
# ...

# %%
binance_currency_name = (binance_coin_details.find("div", class_="mr-md-3 tw-pl-2 md:tw-mb-0 tw-text-xl tw-font-bold tw-mb-0").text).strip()
display("Currency name = ", binance_currency_name)
binance_start_date = binance_coin_details.find("input", class_="text-center px-2 py-1", attrs = {"data-target" : "historical.dateRangeStart", "value" : "2021-08-06"}).text
print("start_date: ", binance_start_date)
binance_end_date = binance_coin_details.find("input", class_="text-center px-2 py-1", attrs = {"data-target" : "historical.dateRangeEnd", "value" :"2021-09-05"}).text
print("end_date: ", binance_end_date)

currency_data_table = (binance_coin_details.find("table", class_ = "table table-striped text-sm text-lg-normal").text).strip()
display(currency_data_table)
# currency_dataframe = pd.DataFrame([currency_data_table],
#                                   columns = )
# display(currency_dataframe)
# Out:
# 'Currency name = '
# 'Binance Coin (BNB)'
# start_date:
# end_date:
# ...

# %% [markdown]
# Currency = "Polkadot (DOT)" start_date = "2021.08.06" end_date = "2021.09.05"

# %%
currency_url = "https://www.coingecko.com/en/coins/polkadot/historical_data/usd?start_date=2021-08-06&end_date=2021-09-05#panel"
polkadot_details = requests.get(currency_url)
polkadot_details
# Out:
# <Response [200]>

# %%
polkadot_coin_details = BeautifulSoup(polkadot_details.text, "html.parser")
print(polkadot_coin_details)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script src="https://www.googleoptimize.com/optimize.js?id=GTM-W3CD992"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/OpensearchDescription.xml" rel="search" type="application/opensearchdescription+xml">
# <title>Polkadot USD Historical Data | CoinGecko</title>
# <meta content="Get Polkadot (DOT) USD historical prices." name="description">
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-NP34MX7');</script>
# ...

# %%
currency_name = (polkadot_coin_details.find("div", class_="mr-md-3 tw-pl-2 md:tw-mb-0 tw-text-xl tw-font-bold tw-mb-0").text).strip()
display("Currency name = ", currency_name)
start_date = polkadot_coin_details.find("input", attrs = {"data-target" : "historical.dateRangeStart"}).text
display("start_date: ", start_date)
end_date = polkadot_coin_details.find("input", attrs = {"data-target" : "historical.dateRangeEnd", "value" :"2021-09-05"}).text
display("end_date: ", end_date)
currency_data_table = polkadot_coin_details.find("table", class_ = "table table-striped text-sm text-lg-normal").text
display(currency_data_table)
# Out:
# 'Currency name = '
# 'Polkadot (DOT)'
# 'start_date: '
# ''
# 'end_date: '
# ''
# ...

# %% [markdown]
# #Task 2#
#
# ##Cleaning the concated dataframe##
#
# 1) We need to clean the dataset obtained after concating the three data frames
#
# 2) identify the data cells with missing values. It may look like N/A. This *not applicable* (N/A) may take the values **None, NaN or NaT**.
# This can be viewed using the describe function of pandas, `dataset.describe(include = "all")`
#
# 3) In order to clean the dataset we need to eliminate rows with above mentioned values. We can do this by using the `.dropna()` function of pandas.
# `clean_dataset = dataset.describe(include = "all").dropna()`
#
# *Note:The default axis pandas uses in almost all methods and functions is axis 0 (rows), thus we are not specifying the axis.*
#
# 4)Now we have a clean data set which is ready **to convert into a CSV file**. This can be done using the in-built pandas function `.to_csv("file_name.csv")`. In this case, `clean_dataset.to_csv("currencies_historic_data.csv")`
#
# 5) We now have a ready csv file.

# %% [markdown]
# #Task 3#
#
# ##Performing and displaying some calculations##
#
# 1) To ascertain mean, max, min, we can use the describe function of pandas. `dataframe.describe()` will give us the statistical decriptives of mean, standard deviation, min, max and quartiles as well. This function returns details for all the columns with numeric values. From here we can choose the values we require.
#
# 2) In order to calculate span (maximum minus
# minimum) we can use `described_dataframe.iloc[row_index, column_index]` to pull out all max and min values specified in the resulting dataframe that we received post the above action and pass a subtraction operator between them.
#
# 3) Use `display(variable_name)` to view data details

# %% [markdown]
# #Task 4#
#
# ##Displaying the dataframe or specific parts of it##
#
# 1)Display the dataframe with values sorted by the first column of the dataframe
# in descending order.
# `display(dataframe_name.sort_values(by="column_name", ascending=False))`
# We give the value "False" for ascending order because it has "True" as its default value and we need to display dataframe with values of first column ("market_cap_bitcoin") in descending order
#
# 2)Display the Open prices.
# `open_prices = dataframe_name["open_price_bitcoin", "open_price_binance_coin", "open_price-polkadot"]`
#
# `display(open_prices)`
#
# 3)Display the last 10 day's Open prices.
# `display(open_prices[-10::])`
#
# 4)Display the Open prices for those days where the open prices for each currency
# is bigger than the respective currency's mean. (price > mean)
# `mean = dataframe.decribe().iloc[0]` - taken from task 3
#
# `define a function:
#     def open_price_higher_than_mean(open_price, mean):
#       price_more_than_mean_bitcoin =[]
#       for i in open_price["open_price_bitcoin"]
#           if i > mean.iloc[index_of_bitcoin_mean]:
#             price_more_than_mean_bitcoin.append(i)
#             del i
#       return price_more_than_mean_bitcoin`
#
# Note: These steps have to be repeated for other two cryptocurrencies as well.
